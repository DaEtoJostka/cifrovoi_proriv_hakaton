# %%
import pandas as pd

# Замените 'your_file_path' на путь к вашему файлу
file_path = 'train_dataset_hackaton2023_train.gzip'

# Загрузка данных
data = pd.read_parquet(file_path)
data = data.drop('group_name', axis=1)

# %%
# Проверка на пропущенные значения
print(data.isnull().sum())
# Out:
# customer_id             0
# date_diff_post    2468517
# buy_post                0
# group_name              0
# revenue                 0
# startdatetime           0
# dish_name               0
# ownareaall_sqm          0
# format_name             0
# dtype: int64

# %%
# Анализ уникальных значений для каждой колонки
for column in data.columns:
    print(f"{column}: {data[column].nunique()} unique values")
# Out:
# customer_id: 500000 unique values
# date_diff_post: 61 unique values
# buy_post: 2 unique values
# group_name: 1 unique values
# revenue: 24113 unique values
# startdatetime: 2606874 unique values
# dish_name: 1038 unique values
# ownareaall_sqm: 629 unique values
# format_name: 9 unique values

# %%
data
# Out:
#           customer_id  date_diff_post  buy_post group_name  revenue  \
# 0               29891             9.0         1      train    69.99
# 1               29891             9.0         1      train   190.00
# 2               29891             9.0         1      train     9.99
# 3               29891             9.0         1      train   119.99
# 4               29891             9.0         1      train   119.99
# ...               ...             ...       ...        ...      ...
# 24261974     46661804             NaN         0      train     7.99
# 24261975     46661804             NaN         0      train    84.98
# 24261976     46661804             NaN         0      train    70.03
# 24261977     46661804             NaN         0      train    19.00
# 24261978     46661804             NaN         0      train    17.99
#
#                startdatetime                   dish_name  ownareaall_sqm  \
# 0        2022-12-05 12:03:58              Кинг Фри станд           300.0
# 1        2022-12-05 12:03:58               Чикен Тар-Тар           300.0
# 2        2022-12-05 12:03:58                 Соус Сырный           300.0
# 3        2022-12-05 12:03:58  Энергет.нап. Адреналин Раш           300.0
# 4        2022-12-05 14:28:35              Латте (СТАНД.)           300.0
# ...                      ...                         ...             ...
# 24261974 2023-08-01 18:04:56     Эвервесс Кола джун 0,3л           300.0
# 24261975 2023-08-01 18:04:56              Воппер Джуниор           300.0
# 24261976 2023-08-01 18:04:56            Наггетсы (3 шт.)           300.0
# 24261977 2023-08-01 18:04:56    Сырные Медальоны (3 шт.)           300.0
# 24261978 2023-08-01 18:04:56                Кинг Фри мал           300.0
#
#                                 format_name
# 0         Отдельно стоящий без внешней зоны
# 1         Отдельно стоящий без внешней зоны
# 2         Отдельно стоящий без внешней зоны
# 3         Отдельно стоящий без внешней зоны
# 4         Отдельно стоящий без внешней зоны
# ...                                     ...
# 24261974                 Фудкорт с туалетом
# 24261975                 Фудкорт с туалетом
# 24261976                 Фудкорт с туалетом
# 24261977                 Фудкорт с туалетом
# 24261978                 Фудкорт с туалетом
#
# [12129384 rows x 9 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# Create an instance of the OneHotEncoder
encoder = OneHotEncoder()

# Fit and transform the specified columns
encoded_columns = encoder.fit_transform(data[columns])

# Do this:
encoded_df = pd.DataFrame.sparse.from_spmatrix(encoded_columns, columns=encoder.get_feature_names_out(columns))

# Concatenate the encoded dataframe with the original dataframe
data_encoded = pd.concat([data, encoded_df], axis=1)

# Display the encoded dataframe
data_encoded
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# | Название        | Описание                   | Тип переменной | Комментарий                  |
# |-----------------|----------------------------|----------------|------------------------------|
# | customer_id     | Идентификатор клиента      | int            |                              |
# | group_name      | Группа: train - test       |                | обучение - контроль          |
# | revenue         | Выручка от продажи блюда    | float          | в заказе                     |
# | startdatetime   | Дата и время продажи       | datetime       |                              |
# | dish_name       | Название блюда             | string         |                              |
# | ownareaall_sqm  | Площадь ресторана          | float          |                              |
# | format_name     | Формат ресторана           |                |                              |
# | buy_post        | Таргет 1: флаг оттока      | bool           | Только в train данных        |
# | date_diff_post  | Таргет 2: количество дней   | int            | между последней покупкой в   |
# |                 | между последней покупкой   |                | прошлом и первой в будущем   |
# |                 | в прошлом и первой в        |                |                              |
# |                 | будущем                    |                |                              |

# %%
import plotly.express as px

correlation_matrix = data.corr()
fig = px.imshow(correlation_matrix)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspaces/cifrovoi_proriv_hakaton/analys.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell://codespaces%2Brefactored-space-succotash-74gx7xq4prpfxgg4/workspaces/cifrovoi_proriv_hakaton/analys.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import plotly.express as px
# ----> <a href='vscode-notebook-cell://codespaces%2Brefactored-space-succotash-74gx7xq4prpfxgg4/workspaces/cifrovoi_proriv_hakaton/analys.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> correlation_matrix = data.corr()
#       <a href='vscode-notebook-cell://codespaces%2Brefactored-space-succotash-74gx7xq4prpfxgg4/workspaces/cifrovoi_proriv_hakaton/analys.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> fig = px.imshow(correlation_matrix)
#       <a href='vscode-notebook-cell://codespaces%2Brefactored-space-succotash-74gx7xq4prpfxgg4/workspaces/cifrovoi_proriv_hakaton/analys.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> fig.show()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'train'
